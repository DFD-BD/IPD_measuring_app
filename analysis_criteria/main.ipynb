# %%
import pandas as pd

# %%
path_to_file = '/Users/danielfiuzadosil/Documents/GitHub_Repo/IPD_measuring_app/photos/output/photos_statistics_1259.csv'

# %%
df =  pd.read_csv(path_to_file)
# Out:
#                                                filename  \
# 0                          BD11034 Naoise Sweeney Front
# 1                           BD11791 Thomas Oakley Front
# 2                          BD11055 Cara Highfield Front
# 3                       BD11022 Yi-Wen Doreen Hsu Front
# 4     BD12621 Ee Yu Front Refractives 02-03-2022 15-...
# ...                                                 ...
# 1254               BD12686 Poppy Daly Front Refractives
# 1255                     BD10374 Simon Betts Front.jpeg
# 1256               BD12428 Derek Ngoo Front Refractives
# 1257                     10229 Princy Dinesh Front.jpeg
# 1258        BD12744 Gurvinder Dhamija Front Refractives
#
#                                                filepath target      ipd_px  \
# 0     /Users/danielfiuzadosil/Documents/GitHub_Repo/...   Good  859.307861
# 1     /Users/danielfiuzadosil/Documents/GitHub_Repo/...   Good  940.172325
# ...
